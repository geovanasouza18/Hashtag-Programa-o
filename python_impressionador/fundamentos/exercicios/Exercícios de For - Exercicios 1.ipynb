# %% [markdown]
# # Exercícios
#
# ## 1. Criando um Registro de Hóspedes
#
# Digamos que você está criando o sistema para registrar a chegada de hóspedes em um hotel. No hotel, os hóspedes podem ter quartos com 1, 2, 3 e 4 pessoas. Seu sistema deve conseguir:
#
# 1. Identificar quantas pessoas o hóspede que acabou de chegar vai ter no quarto (perguntando por meio de input)
# 2. De acordo com a quantidade de pessoas do hóspede, ele deve fazer um for para perguntar o cpf e o nome de cada pessoa, a fim de registrá-la no quarto (2 inputs para cada pessoa, 1 para o cpf e outro para o nome)
# 3. O seu programa então deve gerar uma lista com todas as pessoas que ficarão no quarto em que cada item dessa lista é o nome da pessoa e o cpf da pessoa, assim:

# %% [raw]
# quarto = [
#     ['João', 'cpf:00000000000'],
#     ['Julia', 'cpf:11111111111'],
#     ['Marcus', 'cpf:22222222222'],
#     ['Maria', 'cpf:33333333333'],
# ]

# %% [markdown]
# - Para simplificar, não vamos nos preocupar com possibilidades de "tentar colocar mais de 1 hóspede, digitar o cpf errado, etc. Nosso objetivo é treinar a criação de uma rotina de cadastro

# %%
quantidade_pessoas = int(input('Digite a quantidade de pessoas que ficaram em um quarto: '))
quarto = []
for pessoa in range(quantidade_pessoas):
    nome = str(input('Digite o nome da pessoa: '))
    cpf = int(input('Digite o CPF da pessoa (somente números): '))
    hospede = [f'{nome}, CPF: {cpf}']
    quarto.append(hospede)
print(quarto)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 quantidade_pessoas = int(input('Digite a quantidade de pessoas que ficaram em um quarto: '))
#       2 quarto = []
#       3 for pessoa in range(quantidade_pessoas):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# ...

# %% [markdown]
# ## 2. Análise de Vendas
#
# Nesse exercício vamos fazer uma "análise simples" de atingimento de Meta.
#
# Temos uma lista com os vendedores e os valores de vendas e queremos identificar (printar) quais os vendedores que bateram a meta e qual foi o valor que eles venderam.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
for item in vendas:
    if item[1] >= meta:
        print(f'Vendendor(a) {item[0]} bateu a meta. Fez {item[1]} vendas.')
# Out:
# Vendendor(a) João bateu a meta. Fez 15000 vendas.
# Vendendor(a) Julia bateu a meta. Fez 27000 vendas.
# Vendendor(a) Ana bateu a meta. Fez 10300 vendas.

# %% [markdown]
# ## 3. Comparação com Ano Anterior
#
# Digamos que você está analisando as vendas de produtos de um ecommerce e quer identificar quais produtos tiveram no ano de 2020 mais vendas do que no ano de 2019, para reportar isso para a diretoria.
#
# Sua resposta pode ser um print de cada produto, qual foi a venda de 2019, a venda de 2020 e o % de crescimento de 2020 para 2019.
#
# Lembrando, para calcular o % de crescimento de um produto de um ano para o outro, podemos fazer: (vendas_produto2020/vendas_produto2019 - 1)
#
# Dica: lembre do enumerate, ele pode facilitar seu "for"

# %%
produtos = ['iphone', 'galaxy', 'ipad', 'tv', 'máquina de café', 'kindle', 'geladeira', 'adega', 'notebook dell', 'notebook hp', 'notebook asus', 'microsoft surface', 'webcam', 'caixa de som', 'microfone', 'câmera canon']
vendas2019 = [558147,712350,573823,405252,718654,531580,973139,892292,422760,154753,887061,438508,237467,489705,328311,591120]
vendas2020 = [951642,244295,26964,787604,867660,78830,710331,646016,694913,539704,324831,667179,295633,725316,644622,994303]
for i, produto in enumerate(produtos):
    if vendas2020[i] > vendas2019[i]:
        crescimento = vendas2020[i] / vendas2019[i] - 1
        print(f'{produto} vendeu {vendas2019[i]:,} em 2019, vendas em {vendas2020[i]:,} em 2020 e teve um crescimento de {crescimento:.1%}')
# Out:
# iphone vendeu 558,147 em 2019, vendas em 951,642 em 2020 e teve um crescimento de 70.5%
# tv vendeu 405,252 em 2019, vendas em 787,604 em 2020 e teve um crescimento de 94.3%
# máquina de café vendeu 718,654 em 2019, vendas em 867,660 em 2020 e teve um crescimento de 20.7%
# notebook dell vendeu 422,760 em 2019, vendas em 694,913 em 2020 e teve um crescimento de 64.4%
# notebook hp vendeu 154,753 em 2019, vendas em 539,704 em 2020 e teve um crescimento de 248.8%
# microsoft surface vendeu 438,508 em 2019, vendas em 667,179 em 2020 e teve um crescimento de 52.1%
# webcam vendeu 237,467 em 2019, vendas em 295,633 em 2020 e teve um crescimento de 24.5%
# caixa de som vendeu 489,705 em 2019, vendas em 725,316 em 2020 e teve um crescimento de 48.1%
# microfone vendeu 328,311 em 2019, vendas em 644,622 em 2020 e teve um crescimento de 96.3%
# câmera canon vendeu 591,120 em 2019, vendas em 994,303 em 2020 e teve um crescimento de 68.2%

# %% [markdown]
# # Exercícios
#
# ## 4. Calculando % de uma lista
#
# Faremos algo parecido com "filtrar" uma lista. Mais pra frente no curso aprenderemos outras formas de fazer isso, mas com o nosso conhecimentoa atual já conseguimos resolver o desafio.
#
# Digamos que a gente tenha uma lista de vendedores e ao invés de saber todos os vendedores que bateram a meta, eu quero conseguir calcular o % de vendedores que bateram a meta. Ou seja, se temos 10 vendedores e 3 bateram a meta, temos 30% dos vendedores que bateram a meta.

# %%
meta = 10000
vendas = [
    ['João', 15000],
    ['Julia', 27000],
    ['Marcus', 9900],
    ['Maria', 3750],
    ['Ana', 10300],
    ['Alon', 7870],
]
acima_meta = []
for venda in vendas:
    if venda[1] >= meta:
        acima_meta.append(venda)
print(f'{len(acima_meta) / len(vendas):.0%} bateram a meta')
# Out:
# 50% bateram a meta

# %%
#outro exemplo
quant_acima_meta = 0
for venda in vendas:
    if venda[1] >= meta:
        quant_acima_meta +=1
print(f'{quant_acima_meta / len(vendas):.0%} bateram a meta')
# Out:
# 50% bateram a meta
