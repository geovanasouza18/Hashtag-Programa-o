# %%
#Passo 1 - Entrar no sistema da empresa usando o pyautogui
import pyautogui
import time
pyautogui.PAUSE = 0.5
pyautogui.press('win')
pyautogui.write('chrome')
pyautogui.press('enter')
link = 'https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga'
pyautogui.write(link)
pyautogui.press('enter')

#Passo 2 -Navegando o sistema para buscar a base de dado
time.sleep(3)
pyautogui.click(x=376, y=362, clicks=2)
time.sleep(2)

# %%
#Passo 3 - Baixar arquivo
pyautogui.click(x=502, y=368) #clica nos três pontinhos
time.sleep(2)
pyautogui.click(x=525, y=454) #clica na opção download

# %%
#Passo 4 - Calcular indicadores (faturamento e quatidade de produtos vendidos)
import pandas as pd
caminho = r'C:\Users\User\PycharmProjects\MiniCursoPython - Hashtang\python_impressionador\fundamentos\Vendas - Dez.xlsx'
tabela = pd.read_excel(caminho)
display(tabela)

faturamento = tabela['Valor Final'].sum()
print(faturamento)

quant_produtos = tabela['Quantidade'].sum()
print(quant_produtos)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
 # Passo 5 - Enviar email
pyautogui.hotkey('ctrl', 't')
email = 'https://mail.google.com/mail/u/2/#inbox'
pyautogui.write(email)
pyautogui.press('enter')
time.sleep(5)

#Clicar no botão de criar email
pyautogui.click(x=68, y=218)
time.sleep(4)

pyautogui.write('geovana.developer@gmail.com')
pyautogui.press('tab') # seleciona o email

pyautogui.press('tab') # passa para o campo do assunto do email
pyautogui.write('Relatório de Vendas')
pyautogui.press('tab')

#Corpo do email

# %%
time.sleep(3)
print(pyautogui.position())
# Out:
# Point(x=200, y=246)
